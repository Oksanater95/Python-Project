# %% [markdown]
# Data Science
# Oksana Tereshchenia
# As a fresh data scientist at the company StackOverflow, you have been tasked with analyzing this year's developer survey results to find interesting facts and directions in the software development community. Once you're done, your colleagues at the design department will create a report from your analysis results and publish it online. They can't wait to see what interesting facts you uncover!
#
# Data Acquisition and Data Understanding
# 1. Get the data from https://insights.stackoverflow.com/survey and unzip it.
# 2. Load the survey data into a pandas dataframe and display it.
# 3. How many rows does the table have and which columns are present?
# Hint: df.columns shows a list of columns

# %%
import pandas as pd

survey=pd.read_csv('survey_results_public.csv')
print(survey)

nrows=len(survey)
print(nrows)
# Out:
#        ResponseId                      MainBranch                 Age  \
# 0               1  I am a developer by profession  Under 18 years old
# 1               2  I am a developer by profession     35-44 years old
# 2               3  I am a developer by profession     45-54 years old
# 3               4           I am learning to code     18-24 years old
# 4               5  I am a developer by profession     18-24 years old
# ...           ...                             ...                 ...
# 65432       65433  I am a developer by profession     18-24 years old
# 65433       65434  I am a developer by profession     25-34 years old
# 65434       65435  I am a developer by profession     25-34 years old
# 65435       65436  I am a developer by profession     18-24 years old
# 65436       65437     I code primarily as a hobby     18-24 years old
#
#                 Employment                            RemoteWork   Check  \
# 0      Employed, full-time                                Remote  Apples
# 1      Employed, full-time                                Remote  Apples
# 2      Employed, full-time                                Remote  Apples
# 3       Student, full-time                                   NaN  Apples
# 4       Student, full-time                                   NaN  Apples
# ...                    ...                                   ...     ...
# 65432  Employed, full-time                                Remote  Apples
# 65433  Employed, full-time                                Remote  Apples
# 65434  Employed, full-time                             In-person  Apples
# 65435  Employed, full-time  Hybrid (some remote, some in-person)  Apples
# 65436   Student, full-time                                   NaN  Apples
#
#                                         CodingActivities  \
# 0                                                  Hobby
# 1      Hobby;Contribute to open-source projects;Other...
# 2      Hobby;Contribute to open-source projects;Other...
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 65432                      Hobby;School or academic work
# 65433           Hobby;Contribute to open-source projects
# 65434                                              Hobby
# 65435  Hobby;Contribute to open-source projects;Profe...
# 65436                                                NaN
#
#                                                  EdLevel  \
# 0                              Primary/elementary school
# 1           Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2        Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 3      Some college/university study without earning ...
# 4      Secondary school (e.g. American high school, G...
# ...                                                  ...
# 65432       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 65433                                                NaN
# 65434       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 65435  Secondary school (e.g. American high school, G...
# 65436                                                NaN
#
#                                                LearnCode  \
# 0                                 Books / Physical media
# 1      Books / Physical media;Colleague;On the job tr...
# 2      Books / Physical media;Colleague;On the job tr...
# 3      Other online resources (e.g., videos, blogs, f...
# 4      Other online resources (e.g., videos, blogs, f...
# ...                                                  ...
# 65432  On the job training;School (i.e., University, ...
# 65433                                                NaN
# 65434  Other online resources (e.g., videos, blogs, f...
# 65435  On the job training;Other online resources (e....
# 65436                                                NaN
#
#                                          LearnCodeOnline  ... JobSatPoints_6  \
# 0                                                    NaN  ...            NaN
# 1      Technical documentation;Blogs;Books;Written Tu...  ...            0.0
# 2      Technical documentation;Blogs;Books;Written Tu...  ...            NaN
# 3      Stack Overflow;How-to videos;Interactive tutorial  ...            NaN
# 4      Technical documentation;Blogs;Written Tutorial...  ...            NaN
# ...                                                  ...  ...            ...
# 65432                                                NaN  ...            NaN
# 65433                                                NaN  ...            NaN
# 65434  Technical documentation;Stack Overflow;Social ...  ...            NaN
# 65435  Technical documentation;Blogs;Written Tutorial...  ...            0.0
# 65436                                                NaN  ...            NaN
#
#       JobSatPoints_7 JobSatPoints_8 JobSatPoints_9 JobSatPoints_10  \
# 0                NaN            NaN            NaN             NaN
# 1                0.0            0.0            0.0             0.0
# 2                NaN            NaN            NaN             NaN
# 3                NaN            NaN            NaN             NaN
# 4                NaN            NaN            NaN             NaN
# ...              ...            ...            ...             ...
# 65432            NaN            NaN            NaN             NaN
# 65433            NaN            NaN            NaN             NaN
# 65434            NaN            NaN            NaN             NaN
# 65435            0.0            0.0            0.0             0.0
# 65436            NaN            NaN            NaN             NaN
#
#       JobSatPoints_11           SurveyLength SurveyEase ConvertedCompYearly  \
# 0                 NaN                    NaN        NaN                 NaN
# 1                 0.0                    NaN        NaN                 NaN
# 2                 NaN  Appropriate in length       Easy                 NaN
# 3                 NaN               Too long       Easy                 NaN
# 4                 NaN              Too short       Easy                 NaN
# ...               ...                    ...        ...                 ...
# 65432             NaN                    NaN        NaN                 NaN
# 65433             NaN                    NaN        NaN                 NaN
# 65434             NaN                    NaN        NaN                 NaN
# 65435             0.0                    NaN        NaN                 NaN
# 65436             NaN                    NaN        NaN                 NaN
#
#       JobSat
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# ...      ...
# 65432    NaN
# 65433    NaN
# 65434    NaN
# 65435    NaN
# 65436    NaN
#
# [65437 rows x 114 columns]
# 65437

# %%
colnames=survey.columns

print(colnames)
# Out:
# Index(['ResponseId', 'MainBranch', 'Age', 'Employment', 'RemoteWork', 'Check',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        ...
#        'JobSatPoints_6', 'JobSatPoints_7', 'JobSatPoints_8', 'JobSatPoints_9',
#        'JobSatPoints_10', 'JobSatPoints_11', 'SurveyLength', 'SurveyEase',
#        'ConvertedCompYearly', 'JobSat'],
#       dtype='object', length=114)

# %% [markdown]
# 4. Load the schema table into a pandas dataframe and display it. -> Skim the column descriptions to get familiar with the data.
# Research Questions

# %%
schema_df= pd.read_csv('survey_results_schema.csv')
print(schema_df)
# Out:
#        qid            qname  \
# 0     QID2       MainBranch
# 1   QID127              Age
# 2   QID296       Employment
# 3   QID308       RemoteWork
# 4   QID341            Check
# ..     ...              ...
# 82  QID337   JobSatPoints_7
# 83  QID337   JobSatPoints_8
# 84  QID337   JobSatPoints_9
# 85  QID337  JobSatPoints_10
# 86  QID337  JobSatPoints_11
#
#                                              question force_resp type selector
# 0   Which of the following options best describes ...       True   MC     SAVR
# 1                                  What is your age?*       True   MC     SAVR
# 2   Which of the following best describes your cur...       True   MC     MAVR
# 3   Which best describes your current work situation?      False   MC     SAVR
# 4   Just checking to make sure you are paying atte...       True   MC     SAVR
# ..                                                ...        ...  ...      ...
# 82  Learning and using new technology, including p...        NaN   MC     MAVR
# 83  Designing and building environments, databases...        NaN   MC     MAVR
# 84  Being a power user of a tool, developer langua...        NaN   MC     MAVR
# 85       Working with new and/or top-quality hardware        NaN   MC     MAVR
# 86  A well-staffed/sourced internal network that m...        NaN   MC     MAVR
#
# [87 rows x 6 columns]

# %% [markdown]
# 5. What values are present in the column MainBranch and how often are these values present.
# Hint: you can select a column via df[<column name>] and columns (called 'Series' in pandas) have a method called value_counts.

# %%
freq_values=survey['MainBranch'].value_counts()
print(freq_values)
# Out:
# MainBranch
# I am a developer by profession                                                           50207
# I am not primarily a developer, but I write code sometimes as part of my work/studies     6511
# I am learning to code                                                                     3875
# I code primarily as a hobby                                                               3334
# I used to be a developer by profession, but no longer am                                  1510
# Name: count, dtype: int64

# %%
import plotly.express as px

freqval=pd.DataFrame(freq_values).reset_index()


# Rename the columns for clarity
freqval.columns = ['Type of respondent', 'Count']
print(freqval)
# Out:
#                                   Type of respondent  Count
# 0                     I am a developer by profession  50207
# 1  I am not primarily a developer, but I write co...   6511
# 2                              I am learning to code   3875
# 3                        I code primarily as a hobby   3334
# 4  I used to be a developer by profession, but no...   1510

# %% [markdown]
# 6. How high is the percentage of professional developers, who also code as a hobby?

# %%
profdev=survey[survey['MainBranch']== 'I am a developer by profession']
hobbyprof=profdev['CodingActivities'].apply(
        lambda x: isinstance(x, str) # ensures that x is a string before calling split
        and 'Hobby' in x.split(";")
) #checking if the string Hobby is present. Output is a logical operator
total_profdev=len(profdev['MainBranch'])
print(total_profdev)
#finding how many trues are present on the hobbyproof
total_hobby=len(hobbyprof[hobbyprof == True])
print(total_hobby)
#calculating percentage of hobbyitst among professional developers
hobbyists=total_hobby*100/total_profdev
print(f"{hobbyists:.2f}% of professional developers code as hobby")
# Out:
# 50207
# 32039
# 63.81% of professional developers code as hobby

# %% [markdown]
# 7.Plot the age distribution of German developers.

# %%
#make a list with the name of the columns
colnameslist= survey.columns.tolist()
print(colnameslist)
# Out:
# ['ResponseId', 'MainBranch', 'Age', 'Employment', 'RemoteWork', 'Check', 'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline', 'TechDoc', 'YearsCode', 'YearsCodePro', 'DevType', 'OrgSize', 'PurchaseInfluence', 'BuyNewTool', 'BuildvsBuy', 'TechEndorse', 'Country', 'Currency', 'CompTotal', 'LanguageHaveWorkedWith', 'LanguageWantToWorkWith', 'LanguageAdmired', 'DatabaseHaveWorkedWith', 'DatabaseWantToWorkWith', 'DatabaseAdmired', 'PlatformHaveWorkedWith', 'PlatformWantToWorkWith', 'PlatformAdmired', 'WebframeHaveWorkedWith', 'WebframeWantToWorkWith', 'WebframeAdmired', 'EmbeddedHaveWorkedWith', 'EmbeddedWantToWorkWith', 'EmbeddedAdmired', 'MiscTechHaveWorkedWith', 'MiscTechWantToWorkWith', 'MiscTechAdmired', 'ToolsTechHaveWorkedWith', 'ToolsTechWantToWorkWith', 'ToolsTechAdmired', 'NEWCollabToolsHaveWorkedWith', 'NEWCollabToolsWantToWorkWith', 'NEWCollabToolsAdmired', 'OpSysPersonal use', 'OpSysProfessional use', 'OfficeStackAsyncHaveWorkedWith', 'OfficeStackAsyncWantToWorkWith', 'OfficeStackAsyncAdmired', 'OfficeStackSyncHaveWorkedWith', 'OfficeStackSyncWantToWorkWith', 'OfficeStackSyncAdmired', 'AISearchDevHaveWorkedWith', 'AISearchDevWantToWorkWith', 'AISearchDevAdmired', 'NEWSOSites', 'SOVisitFreq', 'SOAccount', 'SOPartFreq', 'SOHow', 'SOComm', 'AISelect', 'AISent', 'AIBen', 'AIAcc', 'AIComplex', 'AIToolCurrently Using', 'AIToolInterested in Using', 'AIToolNot interested in Using', 'AINextMuch more integrated', 'AINextNo change', 'AINextMore integrated', 'AINextLess integrated', 'AINextMuch less integrated', 'AIThreat', 'AIEthics', 'AIChallenges', 'TBranch', 'ICorPM', 'WorkExp', 'Knowledge_1', 'Knowledge_2', 'Knowledge_3', 'Knowledge_4', 'Knowledge_5', 'Knowledge_6', 'Knowledge_7', 'Knowledge_8', 'Knowledge_9', 'Frequency_1', 'Frequency_2', 'Frequency_3', 'TimeSearching', 'TimeAnswering', 'Frustration', 'ProfessionalTech', 'ProfessionalCloud', 'ProfessionalQuestion', 'Industry', 'JobSatPoints_1', 'JobSatPoints_4', 'JobSatPoints_5', 'JobSatPoints_6', 'JobSatPoints_7', 'JobSatPoints_8', 'JobSatPoints_9', 'JobSatPoints_10', 'JobSatPoints_11', 'SurveyLength', 'SurveyEase', 'ConvertedCompYearly', 'JobSat']

# %%
# #first create a filter 
germanage=survey[survey['Country']=='Germany']
print (germanage)
# Out:
#        ResponseId                                         MainBranch  \
# 18             19                     I am a developer by profession
# 20             21  I am not primarily a developer, but I write co...
# 21             22                     I am a developer by profession
# 48             49                     I am a developer by profession
# 49             50                     I am a developer by profession
# ...           ...                                                ...
# 65163       65164                     I am a developer by profession
# 65181       65182                     I am a developer by profession
# 65334       65335                     I am a developer by profession
# 65371       65372  I am not primarily a developer, but I write co...
# 65435       65436                     I am a developer by profession
#
#                      Age                                         Employment  \
# 18       25-34 years old                                Employed, full-time
# 20       25-34 years old                                Employed, full-time
# 21       35-44 years old                                Employed, full-time
# 48     65 years or older  Independent contractor, freelancer, or self-em...
# 49       25-34 years old                                Employed, full-time
# ...                  ...                                                ...
# 65163    18-24 years old                                Employed, full-time
# 65181    25-34 years old                                Employed, full-time
# 65334    18-24 years old             Student, full-time;Employed, part-time
# 65371    25-34 years old                                Employed, full-time
# 65435    18-24 years old                                Employed, full-time
#
#                                  RemoteWork   Check  \
# 18     Hybrid (some remote, some in-person)  Apples
# 20     Hybrid (some remote, some in-person)  Apples
# 21                                In-person  Apples
# 48                                   Remote  Apples
# 49                                   Remote  Apples
# ...                                     ...     ...
# 65163  Hybrid (some remote, some in-person)  Apples
# 65181  Hybrid (some remote, some in-person)  Apples
# 65334  Hybrid (some remote, some in-person)  Apples
# 65371  Hybrid (some remote, some in-person)  Apples
# 65435  Hybrid (some remote, some in-person)  Apples
#
#                                         CodingActivities  \
# 18     Hobby;Professional development or self-paced l...
# 20     Hobby;Professional development or self-paced l...
# 21                                                 Hobby
# 48                                                 Hobby
# 49     Hobby;Professional development or self-paced l...
# ...                                                  ...
# 65163  Hobby;Professional development or self-paced l...
# 65181                                              Hobby
# 65334  Hobby;Bootstrapping a business;School or acade...
# 65371  Hobby;Professional development or self-paced l...
# 65435  Hobby;Contribute to open-source projects;Profe...
#
#                                                  EdLevel  \
# 18     Some college/university study without earning ...
# 20       Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 21       Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 48     Some college/university study without earning ...
# 49     Some college/university study without earning ...
# ...                                                  ...
# 65163                Associate degree (A.A., A.S., etc.)
# 65181       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 65334  Secondary school (e.g. American high school, G...
# 65371    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 65435  Secondary school (e.g. American high school, G...
#
#                                                LearnCode  \
# 18     Books / Physical media;On the job training;Oth...
# 20     Other online resources (e.g., videos, blogs, f...
# 21     Books / Physical media;Colleague;On the job tr...
# 48     Books / Physical media;Other online resources ...
# 49     Books / Physical media;On the job training;Oth...
# ...                                                  ...
# 65163  On the job training;Other online resources (e....
# 65181  Books / Physical media;Colleague;On the job tr...
# 65334  Other online resources (e.g., videos, blogs, f...
# 65371  Books / Physical media;Other online resources ...
# 65435  On the job training;Other online resources (e....
#
#                                          LearnCodeOnline  ... JobSatPoints_6  \
# 18     Technical documentation;Blogs;Books;Stack Over...  ...           60.0
# 20     Written Tutorials;Stack Overflow;Interactive t...  ...          100.0
# 21     Technical documentation;Blogs;Books;Written Tu...  ...            NaN
# 48     Technical documentation;Blogs;Books;Written Tu...  ...            NaN
# 49     Technical documentation;Blogs;Books;Written Tu...  ...            0.0
# ...                                                  ...  ...            ...
# 65163  Technical documentation;Written Tutorials;Stac...  ...           50.0
# 65181  Technical documentation;Blogs;Books;Written Tu...  ...            NaN
# 65334   Technical documentation;Blogs;Books;Social Media  ...            NaN
# 65371  Technical documentation;Blogs;Books;Written Tu...  ...            NaN
# 65435  Technical documentation;Blogs;Written Tutorial...  ...            0.0
#
#       JobSatPoints_7 JobSatPoints_8 JobSatPoints_9 JobSatPoints_10  \
# 18              10.0           10.0            0.0             0.0
# 20              90.0           90.0          100.0            90.0
# 21               NaN            NaN            NaN             NaN
# 48               NaN            NaN            NaN             NaN
# 49               0.0            0.0            0.0             0.0
# ...              ...            ...            ...             ...
# 65163           40.0           60.0           80.0            90.0
# 65181            NaN            NaN            NaN             NaN
# 65334            NaN            NaN            NaN             NaN
# 65371            NaN            NaN            NaN             NaN
# 65435            0.0            0.0            0.0             0.0
#
#       JobSatPoints_11           SurveyLength                  SurveyEase  \
# 18                0.0  Appropriate in length                        Easy
# 20              100.0  Appropriate in length                        Easy
# 21                NaN  Appropriate in length                        Easy
# 48                NaN  Appropriate in length  Neither easy nor difficult
# 49                0.0  Appropriate in length                        Easy
# ...               ...                    ...                         ...
# 65163            75.0  Appropriate in length  Neither easy nor difficult
# 65181             NaN  Appropriate in length                        Easy
# 65334             NaN                    NaN                         NaN
# 65371             NaN                    NaN                         NaN
# 65435             0.0                    NaN                         NaN
#
#       ConvertedCompYearly JobSat
# 18                    NaN   10.0
# 20                    NaN    6.0
# 21                    NaN    NaN
# 48                    NaN    NaN
# 49                    NaN    3.0
# ...                   ...    ...
# 65163                 NaN    9.0
# 65181                 NaN    NaN
# 65334                 NaN    NaN
# 65371                 NaN    NaN
# 65435                 NaN    NaN
#
# [4947 rows x 114 columns]

# %%
#make violin plot
import plotly.express as px
fig=px.violin(germanage, y='Age')
fig.show()

# %% [markdown]
# What are the 3 most popular databases ?
# 8.1 Check out the column DatabaseWorkedWith. Look at the format of the values.
# 8.2 The format is complicated to work with (semicolon-separated-values). To help with this, you can use the helper function expand_column. Try out the function and understand what it does.
# 8.3 After expanding the column DatabaseWorkedWith, you can filter the columns of the dataframe, to only contain columns from the expansion. Hint: you can filter the columns of a dataframe like this: filtered_df = df[<list of column names>] (example: filtered_df = df[['col_a', 'col_b']]).
# 8.4 To finish the task, you might want to look at the dataframe methods sum and sort_values.

# %%
def expand_column(df, col):
    #"Expand a column with semicolon-separated-values into multiple boolean columns, one for each value in the original column."

    df = df.copy()

    if col not in df.columns:
        raise ValueError(f"Column {col} not found in DataFrame")

    values = set()
    for row in df[col]:
        if not pd.isna(row):
            for value in row.split(";"):
                values.add(value)

    for value in values:
        df[f"{col}_{value}"] = df[col].map(
            lambda v: value in v.split(";") if not pd.isna(v) else False
        )
    return df

# %%
df = pd.read_csv("survey_results_public.csv")
expand_column(df, "DatabaseHaveWorkedWith")
# Out:
#        ResponseId                      MainBranch                 Age  \
# 0               1  I am a developer by profession  Under 18 years old
# 1               2  I am a developer by profession     35-44 years old
# 2               3  I am a developer by profession     45-54 years old
# 3               4           I am learning to code     18-24 years old
# 4               5  I am a developer by profession     18-24 years old
# ...           ...                             ...                 ...
# 65432       65433  I am a developer by profession     18-24 years old
# 65433       65434  I am a developer by profession     25-34 years old
# 65434       65435  I am a developer by profession     25-34 years old
# 65435       65436  I am a developer by profession     18-24 years old
# 65436       65437     I code primarily as a hobby     18-24 years old
#
#                 Employment                            RemoteWork   Check  \
# 0      Employed, full-time                                Remote  Apples
# 1      Employed, full-time                                Remote  Apples
# 2      Employed, full-time                                Remote  Apples
# 3       Student, full-time                                   NaN  Apples
# 4       Student, full-time                                   NaN  Apples
# ...                    ...                                   ...     ...
# 65432  Employed, full-time                                Remote  Apples
# 65433  Employed, full-time                                Remote  Apples
# 65434  Employed, full-time                             In-person  Apples
# 65435  Employed, full-time  Hybrid (some remote, some in-person)  Apples
# 65436   Student, full-time                                   NaN  Apples
#
#                                         CodingActivities  \
# 0                                                  Hobby
# 1      Hobby;Contribute to open-source projects;Other...
# 2      Hobby;Contribute to open-source projects;Other...
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 65432                      Hobby;School or academic work
# 65433           Hobby;Contribute to open-source projects
# 65434                                              Hobby
# 65435  Hobby;Contribute to open-source projects;Profe...
# 65436                                                NaN
#
#                                                  EdLevel  \
# 0                              Primary/elementary school
# 1           Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2        Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 3      Some college/university study without earning ...
# 4      Secondary school (e.g. American high school, G...
# ...                                                  ...
# 65432       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 65433                                                NaN
# 65434       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 65435  Secondary school (e.g. American high school, G...
# 65436                                                NaN
#
#                                                LearnCode  \
# 0                                 Books / Physical media
# 1      Books / Physical media;Colleague;On the job tr...
# 2      Books / Physical media;Colleague;On the job tr...
# 3      Other online resources (e.g., videos, blogs, f...
# 4      Other online resources (e.g., videos, blogs, f...
# ...                                                  ...
# 65432  On the job training;School (i.e., University, ...
# 65433                                                NaN
# 65434  Other online resources (e.g., videos, blogs, f...
# 65435  On the job training;Other online resources (e....
# 65436                                                NaN
#
#                                          LearnCodeOnline  ...  \
# 0                                                    NaN  ...
# 1      Technical documentation;Blogs;Books;Written Tu...  ...
# 2      Technical documentation;Blogs;Books;Written Tu...  ...
# 3      Stack Overflow;How-to videos;Interactive tutorial  ...
# 4      Technical documentation;Blogs;Written Tutorial...  ...
# ...                                                  ...  ...
# 65432                                                NaN  ...
# 65433                                                NaN  ...
# 65434  Technical documentation;Stack Overflow;Social ...  ...
# 65435  Technical documentation;Blogs;Written Tutorial...  ...
# 65436                                                NaN  ...
#
#       DatabaseHaveWorkedWith_Cockroachdb DatabaseHaveWorkedWith_TiDB  \
# 0                                  False                       False
# 1                                  False                       False
# 2                                  False                       False
# 3                                  False                       False
# 4                                  False                       False
# ...                                  ...                         ...
# 65432                              False                       False
# 65433                              False                       False
# 65434                              False                       False
# 65435                              False                       False
# 65436                              False                       False
#
#       DatabaseHaveWorkedWith_Couchbase  \
# 0                                False
# 1                                False
# 2                                False
# 3                                False
# 4                                False
# ...                                ...
# 65432                            False
# 65433                            False
# 65434                            False
# 65435                            False
# 65436                            False
#
#       DatabaseHaveWorkedWith_Microsoft SQL Server  \
# 0                                           False
# 1                                           False
# 2                                           False
# 3                                           False
# 4                                           False
# ...                                           ...
# 65432                                       False
# 65433                                       False
# 65434                                       False
# 65435                                       False
# 65436                                       False
#
#       DatabaseHaveWorkedWith_MariaDB DatabaseHaveWorkedWith_Elasticsearch  \
# 0                              False                                False
# 1                              False                                False
# 2                              False                                False
# 3                              False                                False
# 4                              False                                False
# ...                              ...                                  ...
# 65432                          False                                False
# 65433                          False                                False
# 65434                          False                                False
# 65435                          False                                False
# 65436                          False                                False
#
#       DatabaseHaveWorkedWith_DuckDB DatabaseHaveWorkedWith_Firebird  \
# 0                             False                           False
# 1                             False                           False
# 2                             False                           False
# 3                             False                           False
# 4                             False                           False
# ...                             ...                             ...
# 65432                         False                           False
# 65433                         False                           False
# 65434                         False                           False
# 65435                         False                           False
# 65436                         False                           False
#
#       DatabaseHaveWorkedWith_Cosmos DB DatabaseHaveWorkedWith_SQLite
# 0                                False                         False
# 1                                False                         False
# 2                                False                         False
# 3                                False                          True
# 4                                False                          True
# ...                                ...                           ...
# 65432                            False                         False
# 65433                            False                         False
# 65434                            False                         False
# 65435                            False                          True
# 65436                            False                         False
#
# [65437 rows x 149 columns]

# %%
#function modified so that the output can be already in the shape of a dataframe


def expand_column(df, col):
    #"Expand a column with semicolon-separated-values into multiple boolean columns, one for each value in the original column."

    df = df.copy()

    if col not in df.columns:
        raise ValueError(f"Column {col} not found in DataFrame")

    values = set()
    for row in df[col]:
        if not pd.isna(row):
            for value in row.split(";"):
                values.add(value)

    for value in values:
        df[f"{col}_{value}"] = df[col].map(
            lambda v: value in v.split(";") if not pd.isna(v) else False
        )
# Filter the new columns with the pattern
    new_columns = [new_col for new_col in df.columns if new_col.startswith(f"{col}_")]
    expanded_columns_df = df[new_columns]
    
    return expanded_columns_df

# %%
df = pd.read_csv("survey_results_public.csv")
expand_column(df, "DatabaseHaveWorkedWith")
# Out:
#        DatabaseHaveWorkedWith_Clickhouse  DatabaseHaveWorkedWith_Cassandra  \
# 0                                  False                             False
# 1                                  False                             False
# 2                                  False                             False
# 3                                  False                             False
# 4                                  False                             False
# ...                                  ...                               ...
# 65432                              False                             False
# 65433                              False                             False
# 65434                              False                             False
# 65435                              False                             False
# 65436                              False                             False
#
#        DatabaseHaveWorkedWith_EventStoreDB  DatabaseHaveWorkedWith_Supabase  \
# 0                                    False                            False
# 1                                    False                            False
# 2                                    False                            False
# 3                                    False                            False
# 4                                    False                            False
# ...                                    ...                              ...
# 65432                                False                            False
# 65433                                False                            False
# 65434                                False                            False
# 65435                                False                            False
# 65436                                False                            False
#
#        DatabaseHaveWorkedWith_Databricks SQL  DatabaseHaveWorkedWith_Redis  \
# 0                                      False                         False
# 1                                      False                         False
# 2                                      False                         False
# 3                                      False                         False
# 4                                      False                         False
# ...                                      ...                           ...
# 65432                                  False                         False
# 65433                                  False                         False
# 65434                                  False                         False
# 65435                                  False                         False
# 65436                                  False                         False
#
#        DatabaseHaveWorkedWith_Solr  DatabaseHaveWorkedWith_PostgreSQL  \
# 0                            False                              False
# 1                            False                               True
# 2                            False                              False
# 3                            False                               True
# 4                            False                               True
# ...                            ...                                ...
# 65432                        False                              False
# 65433                        False                              False
# 65434                        False                              False
# 65435                        False                               True
# 65436                        False                               True
#
#        DatabaseHaveWorkedWith_Cloud Firestore  DatabaseHaveWorkedWith_H2  ...  \
# 0                                       False                      False  ...
# 1                                       False                      False  ...
# 2                                       False                      False  ...
# 3                                       False                      False  ...
# 4                                       False                      False  ...
# ...                                       ...                        ...  ...
# 65432                                   False                      False  ...
# 65433                                   False                      False  ...
# 65434                                   False                      False  ...
# 65435                                   False                      False  ...
# 65436                                   False                      False  ...
#
#        DatabaseHaveWorkedWith_Cockroachdb  DatabaseHaveWorkedWith_TiDB  \
# 0                                   False                        False
# 1                                   False                        False
# 2                                   False                        False
# 3                                   False                        False
# 4                                   False                        False
# ...                                   ...                          ...
# 65432                               False                        False
# 65433                               False                        False
# 65434                               False                        False
# 65435                               False                        False
# 65436                               False                        False
#
#        DatabaseHaveWorkedWith_Couchbase  \
# 0                                 False
# 1                                 False
# 2                                 False
# 3                                 False
# 4                                 False
# ...                                 ...
# 65432                             False
# 65433                             False
# 65434                             False
# 65435                             False
# 65436                             False
#
#        DatabaseHaveWorkedWith_Microsoft SQL Server  \
# 0                                            False
# 1                                            False
# 2                                            False
# 3                                            False
# 4                                            False
# ...                                            ...
# 65432                                        False
# 65433                                        False
# 65434                                        False
# 65435                                        False
# 65436                                        False
#
#        DatabaseHaveWorkedWith_MariaDB  DatabaseHaveWorkedWith_Elasticsearch  \
# 0                               False                                 False
# 1                               False                                 False
# 2                               False                                 False
# 3                               False                                 False
# 4                               False                                 False
# ...                               ...                                   ...
# 65432                           False                                 False
# 65433                           False                                 False
# 65434                           False                                 False
# 65435                           False                                 False
# 65436                           False                                 False
#
#        DatabaseHaveWorkedWith_DuckDB  DatabaseHaveWorkedWith_Firebird  \
# 0                              False                            False
# 1                              False                            False
# 2                              False                            False
# 3                              False                            False
# 4                              False                            False
# ...                              ...                              ...
# 65432                          False                            False
# 65433                          False                            False
# 65434                          False                            False
# 65435                          False                            False
# 65436                          False                            False
#
#        DatabaseHaveWorkedWith_Cosmos DB  DatabaseHaveWorkedWith_SQLite
# 0                                 False                          False
# 1                                 False                          False
# 2                                 False                          False
# 3                                 False                           True
# 4                                 False                           True
# ...                                 ...                            ...
# 65432                             False                          False
# 65433                             False                          False
# 65434                             False                          False
# 65435                             False                           True
# 65436                             False                          False
#
# [65437 rows x 35 columns]

# %%
new_columns=expand_column(survey, "DatabaseHaveWorkedWith")
print(new_columns)
# Out:
#        DatabaseHaveWorkedWith_Clickhouse  DatabaseHaveWorkedWith_Cassandra  \
# 0                                  False                             False
# 1                                  False                             False
# 2                                  False                             False
# 3                                  False                             False
# 4                                  False                             False
# ...                                  ...                               ...
# 65432                              False                             False
# 65433                              False                             False
# 65434                              False                             False
# 65435                              False                             False
# 65436                              False                             False
#
#        DatabaseHaveWorkedWith_EventStoreDB  DatabaseHaveWorkedWith_Supabase  \
# 0                                    False                            False
# 1                                    False                            False
# 2                                    False                            False
# 3                                    False                            False
# 4                                    False                            False
# ...                                    ...                              ...
# 65432                                False                            False
# 65433                                False                            False
# 65434                                False                            False
# 65435                                False                            False
# 65436                                False                            False
#
#        DatabaseHaveWorkedWith_Databricks SQL  DatabaseHaveWorkedWith_Redis  \
# 0                                      False                         False
# 1                                      False                         False
# 2                                      False                         False
# 3                                      False                         False
# 4                                      False                         False
# ...                                      ...                           ...
# 65432                                  False                         False
# 65433                                  False                         False
# 65434                                  False                         False
# 65435                                  False                         False
# 65436                                  False                         False
#
#        DatabaseHaveWorkedWith_Solr  DatabaseHaveWorkedWith_PostgreSQL  \
# 0                            False                              False
# 1                            False                               True
# 2                            False                              False
# 3                            False                               True
# 4                            False                               True
# ...                            ...                                ...
# 65432                        False                              False
# 65433                        False                              False
# 65434                        False                              False
# 65435                        False                               True
# 65436                        False                               True
#
#        DatabaseHaveWorkedWith_Cloud Firestore  DatabaseHaveWorkedWith_H2  ...  \
# 0                                       False                      False  ...
# 1                                       False                      False  ...
# 2                                       False                      False  ...
# 3                                       False                      False  ...
# 4                                       False                      False  ...
# ...                                       ...                        ...  ...
# 65432                                   False                      False  ...
# 65433                                   False                      False  ...
# 65434                                   False                      False  ...
# 65435                                   False                      False  ...
# 65436                                   False                      False  ...
#
#        DatabaseHaveWorkedWith_Cockroachdb  DatabaseHaveWorkedWith_TiDB  \
# 0                                   False                        False
# 1                                   False                        False
# 2                                   False                        False
# 3                                   False                        False
# 4                                   False                        False
# ...                                   ...                          ...
# 65432                               False                        False
# 65433                               False                        False
# 65434                               False                        False
# 65435                               False                        False
# 65436                               False                        False
#
#        DatabaseHaveWorkedWith_Couchbase  \
# 0                                 False
# 1                                 False
# 2                                 False
# 3                                 False
# 4                                 False
# ...                                 ...
# 65432                             False
# 65433                             False
# 65434                             False
# 65435                             False
# 65436                             False
#
#        DatabaseHaveWorkedWith_Microsoft SQL Server  \
# 0                                            False
# 1                                            False
# 2                                            False
# 3                                            False
# 4                                            False
# ...                                            ...
# 65432                                        False
# 65433                                        False
# 65434                                        False
# 65435                                        False
# 65436                                        False
#
#        DatabaseHaveWorkedWith_MariaDB  DatabaseHaveWorkedWith_Elasticsearch  \
# 0                               False                                 False
# 1                               False                                 False
# 2                               False                                 False
# 3                               False                                 False
# 4                               False                                 False
# ...                               ...                                   ...
# 65432                           False                                 False
# 65433                           False                                 False
# 65434                           False                                 False
# 65435                           False                                 False
# 65436                           False                                 False
#
#        DatabaseHaveWorkedWith_DuckDB  DatabaseHaveWorkedWith_Firebird  \
# 0                              False                            False
# 1                              False                            False
# 2                              False                            False
# 3                              False                            False
# 4                              False                            False
# ...                              ...                              ...
# 65432                          False                            False
# 65433                          False                            False
# 65434                          False                            False
# 65435                          False                            False
# 65436                          False                            False
#
#        DatabaseHaveWorkedWith_Cosmos DB  DatabaseHaveWorkedWith_SQLite
# 0                                 False                          False
# 1                                 False                          False
# 2                                 False                          False
# 3                                 False                           True
# 4                                 False                           True
# ...                                 ...                            ...
# 65432                             False                          False
# 65433                             False                          False
# 65434                             False                          False
# 65435                             False                           True
# 65436                             False                          False
#
# [65437 rows x 35 columns]

# %%
# sum of each column. True counts as 1 and false counts as 0 automatically
col_sums=new_columns.sum()
print(col_sums)
# Out:
# DatabaseHaveWorkedWith_Clickhouse                      890
# DatabaseHaveWorkedWith_Cassandra                      1268
# DatabaseHaveWorkedWith_EventStoreDB                    162
# DatabaseHaveWorkedWith_Supabase                       2078
# DatabaseHaveWorkedWith_Databricks SQL                 1003
# DatabaseHaveWorkedWith_Redis                         10463
# DatabaseHaveWorkedWith_Solr                            766
# DatabaseHaveWorkedWith_PostgreSQL                    25536
# DatabaseHaveWorkedWith_Cloud Firestore                2842
# DatabaseHaveWorkedWith_H2                             2006
# DatabaseHaveWorkedWith_BigQuery                       2531
# DatabaseHaveWorkedWith_Microsoft Access               2193
# DatabaseHaveWorkedWith_IBM DB2                         914
# DatabaseHaveWorkedWith_Dynamodb                       4138
# DatabaseHaveWorkedWith_Presto                          323
# DatabaseHaveWorkedWith_InfluxDB                       1338
# DatabaseHaveWorkedWith_Firebase Realtime Database     3018
# DatabaseHaveWorkedWith_RavenDB                         159
# DatabaseHaveWorkedWith_Neo4J                           998
# DatabaseHaveWorkedWith_Couch DB                        534
# DatabaseHaveWorkedWith_Datomic                         184
# DatabaseHaveWorkedWith_Oracle                         5273
# DatabaseHaveWorkedWith_Snowflake                      1364
# DatabaseHaveWorkedWith_MongoDB                       13007
# DatabaseHaveWorkedWith_MySQL                         21099
# DatabaseHaveWorkedWith_Cockroachdb                     507
# DatabaseHaveWorkedWith_TiDB                            127
# DatabaseHaveWorkedWith_Couchbase                       353
# DatabaseHaveWorkedWith_Microsoft SQL Server          13275
# DatabaseHaveWorkedWith_MariaDB                        8991
# DatabaseHaveWorkedWith_Elasticsearch                  6533
# DatabaseHaveWorkedWith_DuckDB                          710
# DatabaseHaveWorkedWith_Firebird                        563
# DatabaseHaveWorkedWith_Cosmos DB                      1746
# DatabaseHaveWorkedWith_SQLite                        17365
# dtype: int64

# %%
#reorder the columns in ascending order to identify the top tree databases
top_3_db=col_sums.sort_values(ascending=False).head(3)
# Extract the simplified names (part after the "_") extracts the simplified name of each top database by splitting the column name on the _ and keeping the last part.
top_3_db_names = [col.split('_')[-1] for col in top_3_db.index]
# Print the result
print(f"The three most popular databases are: {', '.join(top_3_db_names)}.")
# Out:
# The three most popular databases are: PostgreSQL, MySQL, SQLite.

# %%
col_sums2=new_columns.sum()
print(col_sums2)

# saving the columns excluding everything that is before the _
# Rename the columns of new_columns dataframe
new_columns.columns = new_columns.columns.str.split('_').str[-1]

# Display the renamed columns
print(new_columns.columns)
print(new_columns)
# Out:
# DatabaseHaveWorkedWith_Clickhouse                      890
# DatabaseHaveWorkedWith_Cassandra                      1268
# DatabaseHaveWorkedWith_EventStoreDB                    162
# DatabaseHaveWorkedWith_Supabase                       2078
# DatabaseHaveWorkedWith_Databricks SQL                 1003
# DatabaseHaveWorkedWith_Redis                         10463
# DatabaseHaveWorkedWith_Solr                            766
# DatabaseHaveWorkedWith_PostgreSQL                    25536
# DatabaseHaveWorkedWith_Cloud Firestore                2842
# DatabaseHaveWorkedWith_H2                             2006
# DatabaseHaveWorkedWith_BigQuery                       2531
# DatabaseHaveWorkedWith_Microsoft Access               2193
# DatabaseHaveWorkedWith_IBM DB2                         914
# DatabaseHaveWorkedWith_Dynamodb                       4138
# DatabaseHaveWorkedWith_Presto                          323
# DatabaseHaveWorkedWith_InfluxDB                       1338
# DatabaseHaveWorkedWith_Firebase Realtime Database     3018
# DatabaseHaveWorkedWith_RavenDB                         159
# DatabaseHaveWorkedWith_Neo4J                           998
# DatabaseHaveWorkedWith_Couch DB                        534
# DatabaseHaveWorkedWith_Datomic                         184
# DatabaseHaveWorkedWith_Oracle                         5273
# DatabaseHaveWorkedWith_Snowflake                      1364
# DatabaseHaveWorkedWith_MongoDB                       13007
# DatabaseHaveWorkedWith_MySQL                         21099
# DatabaseHaveWorkedWith_Cockroachdb                     507
# DatabaseHaveWorkedWith_TiDB                            127
# DatabaseHaveWorkedWith_Couchbase                       353
# DatabaseHaveWorkedWith_Microsoft SQL Server          13275
# DatabaseHaveWorkedWith_MariaDB                        8991
# DatabaseHaveWorkedWith_Elasticsearch                  6533
# DatabaseHaveWorkedWith_DuckDB                          710
# DatabaseHaveWorkedWith_Firebird                        563
# DatabaseHaveWorkedWith_Cosmos DB                      1746
# DatabaseHaveWorkedWith_SQLite                        17365
# dtype: int64
# Index(['Clickhouse', 'Cassandra', 'EventStoreDB', 'Supabase', 'Databricks SQL',
#        'Redis', 'Solr', 'PostgreSQL', 'Cloud Firestore', 'H2', 'BigQuery',
#        'Microsoft Access', 'IBM DB2', 'Dynamodb', 'Presto', 'InfluxDB',
#        'Firebase Realtime Database', 'RavenDB', 'Neo4J', 'Couch DB', 'Datomic',
#        'Oracle', 'Snowflake', 'MongoDB', 'MySQL', 'Cockroachdb', 'TiDB',
#        'Couchbase', 'Microsoft SQL Server', 'MariaDB', 'Elasticsearch',
#        'DuckDB', 'Firebird', 'Cosmos DB', 'SQLite'],
#       dtype='object')
#        Clickhouse  Cassandra  EventStoreDB  Supabase  Databricks SQL  Redis  \
# 0           False      False         False     False           False  False
# 1           False      False         False     False           False  False
# 2           False      False         False     False           False  False
# 3           False      False         False     False           False  False
# 4           False      False         False     False           False  False
# ...           ...        ...           ...       ...             ...    ...
# 65432       False      False         False     False           False  False
# 65433       False      False         False     False           False  False
# 65434       False      False         False     False           False  False
# 65435       False      False         False     False           False  False
# 65436       False      False         False     False           False  False
#
#         Solr  PostgreSQL  Cloud Firestore     H2  ...  Cockroachdb   TiDB  \
# 0      False       False            False  False  ...        False  False
# 1      False        True            False  False  ...        False  False
# 2      False       False            False  False  ...        False  False
# 3      False        True            False  False  ...        False  False
# 4      False        True            False  False  ...        False  False
# ...      ...         ...              ...    ...  ...          ...    ...
# 65432  False       False            False  False  ...        False  False
# 65433  False       False            False  False  ...        False  False
# 65434  False       False            False  False  ...        False  False
# 65435  False        True            False  False  ...        False  False
# 65436  False        True            False  False  ...        False  False
#
#        Couchbase  Microsoft SQL Server  MariaDB  Elasticsearch  DuckDB  \
# 0          False                 False    False          False   False
# 1          False                 False    False          False   False
# 2          False                 False    False          False   False
# 3          False                 False    False          False   False
# 4          False                 False    False          False   False
# ...          ...                   ...      ...            ...     ...
# 65432      False                 False    False          False   False
# 65433      False                 False    False          False   False
# 65434      False                 False    False          False   False
# 65435      False                 False    False          False   False
# 65436      False                 False    False          False   False
#
#        Firebird  Cosmos DB  SQLite
# 0         False      False   False
# 1         False      False   False
# 2         False      False   False
# 3         False      False    True
# 4         False      False    True
# ...         ...        ...     ...
# 65432     False      False   False
# 65433     False      False   False
# 65434     False      False   False
# 65435     False      False    True
# 65436     False      False   False
#
# [65437 rows x 35 columns]

# %%
#transform the output into  dataframe
col_sums_df = pd.DataFrame(col_sums2).reset_index()

# Rename the columns for clarity
col_sums_df.columns = ['Database', 'Count']
print(col_sums_df)



fig_db= px.bar(
    col_sums_df, 
    x='Database', 
    y='Count', 
    title='Number of users using each Database',
    labels={'Database': 'Database', 'Count': 'Count'},
    color='Database',  # Optional: adds different colors to the bars
    
)
# Update layout for better appearance
fig_db.update_layout(
    xaxis_title='Database',
    yaxis_title='Number of users',
    title_x=0.5,  # Center the title
    template='plotly_white',
    showlegend=False  # Use a clean white background
)
# Show the plot
fig_db.show()
# Out:
#                                              Database  Count
# 0                   DatabaseHaveWorkedWith_Clickhouse    890
# 1                    DatabaseHaveWorkedWith_Cassandra   1268
# 2                 DatabaseHaveWorkedWith_EventStoreDB    162
# 3                     DatabaseHaveWorkedWith_Supabase   2078
# 4               DatabaseHaveWorkedWith_Databricks SQL   1003
# 5                        DatabaseHaveWorkedWith_Redis  10463
# 6                         DatabaseHaveWorkedWith_Solr    766
# 7                   DatabaseHaveWorkedWith_PostgreSQL  25536
# 8              DatabaseHaveWorkedWith_Cloud Firestore   2842
# 9                           DatabaseHaveWorkedWith_H2   2006
# 10                    DatabaseHaveWorkedWith_BigQuery   2531
# 11            DatabaseHaveWorkedWith_Microsoft Access   2193
# 12                     DatabaseHaveWorkedWith_IBM DB2    914
# 13                    DatabaseHaveWorkedWith_Dynamodb   4138
# 14                      DatabaseHaveWorkedWith_Presto    323
# 15                    DatabaseHaveWorkedWith_InfluxDB   1338
# 16  DatabaseHaveWorkedWith_Firebase Realtime Database   3018
# 17                     DatabaseHaveWorkedWith_RavenDB    159
# 18                       DatabaseHaveWorkedWith_Neo4J    998
# 19                    DatabaseHaveWorkedWith_Couch DB    534
# 20                     DatabaseHaveWorkedWith_Datomic    184
# 21                      DatabaseHaveWorkedWith_Oracle   5273
# 22                   DatabaseHaveWorkedWith_Snowflake   1364
# 23                     DatabaseHaveWorkedWith_MongoDB  13007
# 24                       DatabaseHaveWorkedWith_MySQL  21099
# 25                 DatabaseHaveWorkedWith_Cockroachdb    507
# 26                        DatabaseHaveWorkedWith_TiDB    127
# 27                   DatabaseHaveWorkedWith_Couchbase    353
# 28        DatabaseHaveWorkedWith_Microsoft SQL Server  13275
# 29                     DatabaseHaveWorkedWith_MariaDB   8991
# 30               DatabaseHaveWorkedWith_Elasticsearch   6533
# 31                      DatabaseHaveWorkedWith_DuckDB    710
# 32                    DatabaseHaveWorkedWith_Firebird    563
# 33                   DatabaseHaveWorkedWith_Cosmos DB   1746
# 34                      DatabaseHaveWorkedWith_SQLite  17365

# %% [markdown]
# 9. Is there a difference between programming languages when it comes to job satisfaction?
# In this task we want to calculate the mean job satisfaction for each programming language.
#
# 9.1 Check out the column LanguageWorkedWith and expand it as you did in question 8.
# 9.2 Check out the column JobSat: What values does it have?
# 9.3 Map the values of the column JobSat to numerical values from 1 to 5 (with 5 being the highest job satisfaction).
# 9.3.1 Write a function that gets a job satisfaction string as its input and returns the according number.
# 9.3.2 Create a new column JobSatNum in the dataframe, which contains the numerical job satisfaction value. Hint: df['JobSatNum'] = df['JobSat'].map(<your mapping function>)
# 9.4 Print the mean numerical job satisfaction for each programming language. Hint: Loop through the column names of the programming language columns you created in 9.1. For each programming language, filter the dataframe, to only contain the rows where the programming language column has the value True. From the filtered dataframe, select the column containing the numerical job satisfaction value and compute the mean (pandas Series have a method mean).

# %%
def expand_column1(df, col):
    
    df = df.copy()

    if col not in df.columns:
        raise ValueError(f"Column {col} not found in DataFrame")

    values = set()
    for row in df[col]:
        if not pd.isna(row):
            for value in row.split(";"):
                values.add(value)

    for value in values:
        df[f"{col}_{value}"] = df[col].map(
            lambda v: value in v.split(";") if not pd.isna(v) else False
        )
    return df

# %%
expand_column1(survey, "LanguageHaveWorkedWith")
# Out:
#        ResponseId                      MainBranch                 Age  \
# 0               1  I am a developer by profession  Under 18 years old
# 1               2  I am a developer by profession     35-44 years old
# 2               3  I am a developer by profession     45-54 years old
# 3               4           I am learning to code     18-24 years old
# 4               5  I am a developer by profession     18-24 years old
# ...           ...                             ...                 ...
# 65432       65433  I am a developer by profession     18-24 years old
# 65433       65434  I am a developer by profession     25-34 years old
# 65434       65435  I am a developer by profession     25-34 years old
# 65435       65436  I am a developer by profession     18-24 years old
# 65436       65437     I code primarily as a hobby     18-24 years old
#
#                 Employment                            RemoteWork   Check  \
# 0      Employed, full-time                                Remote  Apples
# 1      Employed, full-time                                Remote  Apples
# 2      Employed, full-time                                Remote  Apples
# 3       Student, full-time                                   NaN  Apples
# 4       Student, full-time                                   NaN  Apples
# ...                    ...                                   ...     ...
# 65432  Employed, full-time                                Remote  Apples
# 65433  Employed, full-time                                Remote  Apples
# 65434  Employed, full-time                             In-person  Apples
# 65435  Employed, full-time  Hybrid (some remote, some in-person)  Apples
# 65436   Student, full-time                                   NaN  Apples
#
#                                         CodingActivities  \
# 0                                                  Hobby
# 1      Hobby;Contribute to open-source projects;Other...
# 2      Hobby;Contribute to open-source projects;Other...
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 65432                      Hobby;School or academic work
# 65433           Hobby;Contribute to open-source projects
# 65434                                              Hobby
# 65435  Hobby;Contribute to open-source projects;Profe...
# 65436                                                NaN
#
#                                                  EdLevel  \
# 0                              Primary/elementary school
# 1           Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2        Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 3      Some college/university study without earning ...
# 4      Secondary school (e.g. American high school, G...
# ...                                                  ...
# 65432       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 65433                                                NaN
# 65434       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 65435  Secondary school (e.g. American high school, G...
# 65436                                                NaN
#
#                                                LearnCode  \
# 0                                 Books / Physical media
# 1      Books / Physical media;Colleague;On the job tr...
# 2      Books / Physical media;Colleague;On the job tr...
# 3      Other online resources (e.g., videos, blogs, f...
# 4      Other online resources (e.g., videos, blogs, f...
# ...                                                  ...
# 65432  On the job training;School (i.e., University, ...
# 65433                                                NaN
# 65434  Other online resources (e.g., videos, blogs, f...
# 65435  On the job training;Other online resources (e....
# 65436                                                NaN
#
#                                          LearnCodeOnline  ...  \
# 0                                                    NaN  ...
# 1      Technical documentation;Blogs;Books;Written Tu...  ...
# 2      Technical documentation;Blogs;Books;Written Tu...  ...
# 3      Stack Overflow;How-to videos;Interactive tutorial  ...
# 4      Technical documentation;Blogs;Written Tutorial...  ...
# ...                                                  ...  ...
# 65432                                                NaN  ...
# 65433                                                NaN  ...
# 65434  Technical documentation;Stack Overflow;Social ...  ...
# 65435  Technical documentation;Blogs;Written Tutorial...  ...
# 65436                                                NaN  ...
#
#       LanguageHaveWorkedWith_Go LanguageHaveWorkedWith_Rust  \
# 0                         False                       False
# 1                          True                       False
# 2                         False                       False
# 3                         False                       False
# 4                         False                        True
# ...                         ...                         ...
# 65432                     False                       False
# 65433                     False                       False
# 65434                     False                       False
# 65435                      True                        True
# 65436                     False                       False
#
#       LanguageHaveWorkedWith_Python LanguageHaveWorkedWith_F#  \
# 0                             False                     False
# 1                              True                     False
# 2                             False                     False
# 3                              True                     False
# 4                              True                     False
# ...                             ...                       ...
# 65432                         False                     False
# 65433                         False                     False
# 65434                         False                     False
# 65435                          True                     False
# 65436                          True                     False
#
#       LanguageHaveWorkedWith_Ruby LanguageHaveWorkedWith_Scala  \
# 0                           False                        False
# 1                           False                        False
# 2                           False                        False
# 3                           False                        False
# 4                           False                        False
# ...                           ...                          ...
# 65432                       False                        False
# 65433                       False                        False
# 65434                       False                        False
# 65435                       False                        False
# 65436                       False                        False
#
#       LanguageHaveWorkedWith_Elixir LanguageHaveWorkedWith_Delphi  \
# 0                             False                         False
# 1                             False                         False
# 2                             False                         False
# 3                             False                         False
# 4                             False                         False
# ...                             ...                           ...
# 65432                         False                         False
# 65433                         False                         False
# 65434                         False                         False
# 65435                         False                         False
# 65436                         False                         False
#
#       LanguageHaveWorkedWith_R LanguageHaveWorkedWith_Java
# 0                        False                       False
# 1                        False                        True
# 2                        False                       False
# 3                        False                        True
# 4                        False                       False
# ...                        ...                         ...
# 65432                    False                       False
# 65433                    False                       False
# 65434                    False                       False
# 65435                    False                       False
# 65436                    False                        True
#
# [65437 rows x 163 columns]

# %%
#9.2 What values does the column JobSat have?
#checking value counts

jobsat_counts= survey['JobSat'].value_counts()
print(jobsat_counts)
# Out:
# JobSat
# 8.0     7509
# 7.0     6379
# 6.0     3751
# 9.0     3626
# 10.0    2251
# 5.0     1956
# 3.0     1165
# 4.0     1130
# 2.0      772
# 0.0      311
# 1.0      276
# Name: count, dtype: int64

# %%
#it is also possibel to retrieve the values with the function unique
# Retrieving unique values
unique_values = survey['JobSat'].unique()

# Display the result
print(unique_values)
# Out:
# [nan  8.  5. 10.  6.  9.  4.  7.  3.  2.  1.  0.]

# %%
#9.3 Map the values of the column JobSat to numerical values from 1 to 5 (with 5 being the highest job satisfaction).
print("the values range between", survey['JobSat'].min(), "and", survey['JobSat'].max())
# Out:
# the values range between 0.0 and 10.0

# %%
#9.3 Map the values of the column JobSat to numerical values from 1 to 5 (with 5 being the highest job satisfaction).
satisfaction = survey['JobSat'].apply(
    lambda x: 5 if x >= 9 else 
              (4 if 7 <= x < 9 else 
               (3 if 5 <= x < 7 else 
                (2 if 3 <= x < 5 else 
                 1)))  if pd.notna(x) else None
)
print(satisfaction)
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#          ..
# 65432   NaN
# 65433   NaN
# 65434   NaN
# 65435   NaN
# 65436   NaN
# Name: JobSat, Length: 65437, dtype: float64

# %%
def sat_score(string):
    # Defining the score for the string through a dictionary
    rating = {
        "Very Low": 1,
        "Low": 2,
        "Neutral": 3,
        "High": 4,
        "Very High": 5
    }
    
    # Use .get() to safely get the corresponding score
    score = rating.get(string, None)
    
    if score is None:
        print("This is not a valid string. Please, enter one of the following options: Very Low, Low, Neutral, High or Very High")
        return None  # Return None if the string is invalid
    
    # If the string is valid, print the corresponding score
    print(f"The score for '{string}' is {score}.")
    return score  # Return the score

# %%
print(sat_score("Neutral"))
# Out:
# The score for 'Neutral' is 3.
# 3

# %%
print(sat_score("Excellent"))
# Out:
# This is not a valid string. Please, enter one of the following options: Very Low, Low, Neutral, High or Very High
# None

# %%
#9.3.2 Create a new column JobSatNum in the dataframe, which contains the numerical job satisfaction value. 
# Hint: df['JobSatNum'] = df['JobSat'].map(<your mapping function>)

survey['JobSat_scaled'] = survey['JobSat'].map(
    lambda x: 5 if x >= 9 else 
              (4 if 7 <= x < 9 else 
               (3 if 5 <= x < 7 else 
                (2 if 3 <= x < 5 else 
                 1)))  if pd.notna(x) else None
)

print(survey['JobSat_scaled'])
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#          ..
# 65432   NaN
# 65433   NaN
# 65434   NaN
# 65435   NaN
# 65436   NaN
# Name: JobSat_scaled, Length: 65437, dtype: float64

# %%
jobsatscaled_counts=survey['JobSat_scaled'].value_counts()
print(jobsatscaled_counts)
# Out:
# JobSat_scaled
# 4.0    13888
# 5.0     5877
# 3.0     5707
# 2.0     2295
# 1.0     1359
# Name: count, dtype: int64

# %%
fig_pie = px.pie(
    names=jobsatscaled_counts.index,  # Categories from the index of the value_counts
    values=jobsatscaled_counts.values,  # Values from the value_counts
    title='Distribution of Job Satisfaction',
    labels={'value': 'Job Satisfaction Level', 'count': 'Count'},
    
)

fig_pie.update_traces(textinfo='value')
# Show the pie chart
fig_pie.show()

# %%
#new df with expanded columns
lang_df=expand_column1(survey, "LanguageHaveWorkedWith")
print(lang_df)
# Out:
#        ResponseId                      MainBranch                 Age  \
# 0               1  I am a developer by profession  Under 18 years old
# 1               2  I am a developer by profession     35-44 years old
# 2               3  I am a developer by profession     45-54 years old
# 3               4           I am learning to code     18-24 years old
# 4               5  I am a developer by profession     18-24 years old
# ...           ...                             ...                 ...
# 65432       65433  I am a developer by profession     18-24 years old
# 65433       65434  I am a developer by profession     25-34 years old
# 65434       65435  I am a developer by profession     25-34 years old
# 65435       65436  I am a developer by profession     18-24 years old
# 65436       65437     I code primarily as a hobby     18-24 years old
#
#                 Employment                            RemoteWork   Check  \
# 0      Employed, full-time                                Remote  Apples
# 1      Employed, full-time                                Remote  Apples
# 2      Employed, full-time                                Remote  Apples
# 3       Student, full-time                                   NaN  Apples
# 4       Student, full-time                                   NaN  Apples
# ...                    ...                                   ...     ...
# 65432  Employed, full-time                                Remote  Apples
# 65433  Employed, full-time                                Remote  Apples
# 65434  Employed, full-time                             In-person  Apples
# 65435  Employed, full-time  Hybrid (some remote, some in-person)  Apples
# 65436   Student, full-time                                   NaN  Apples
#
#                                         CodingActivities  \
# 0                                                  Hobby
# 1      Hobby;Contribute to open-source projects;Other...
# 2      Hobby;Contribute to open-source projects;Other...
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 65432                      Hobby;School or academic work
# 65433           Hobby;Contribute to open-source projects
# 65434                                              Hobby
# 65435  Hobby;Contribute to open-source projects;Profe...
# 65436                                                NaN
#
#                                                  EdLevel  \
# 0                              Primary/elementary school
# 1           Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2        Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 3      Some college/university study without earning ...
# 4      Secondary school (e.g. American high school, G...
# ...                                                  ...
# 65432       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 65433                                                NaN
# 65434       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 65435  Secondary school (e.g. American high school, G...
# 65436                                                NaN
#
#                                                LearnCode  \
# 0                                 Books / Physical media
# 1      Books / Physical media;Colleague;On the job tr...
# 2      Books / Physical media;Colleague;On the job tr...
# 3      Other online resources (e.g., videos, blogs, f...
# 4      Other online resources (e.g., videos, blogs, f...
# ...                                                  ...
# 65432  On the job training;School (i.e., University, ...
# 65433                                                NaN
# 65434  Other online resources (e.g., videos, blogs, f...
# 65435  On the job training;Other online resources (e....
# 65436                                                NaN
#
#                                          LearnCodeOnline  ...  \
# 0                                                    NaN  ...
# 1      Technical documentation;Blogs;Books;Written Tu...  ...
# 2      Technical documentation;Blogs;Books;Written Tu...  ...
# 3      Stack Overflow;How-to videos;Interactive tutorial  ...
# 4      Technical documentation;Blogs;Written Tutorial...  ...
# ...                                                  ...  ...
# 65432                                                NaN  ...
# 65433                                                NaN  ...
# 65434  Technical documentation;Stack Overflow;Social ...  ...
# 65435  Technical documentation;Blogs;Written Tutorial...  ...
# 65436                                                NaN  ...
#
#       LanguageHaveWorkedWith_Go LanguageHaveWorkedWith_Rust  \
# 0                         False                       False
# 1                          True                       False
# 2                         False                       False
# 3                         False                       False
# 4                         False                        True
# ...                         ...                         ...
# 65432                     False                       False
# 65433                     False                       False
# 65434                     False                       False
# 65435                      True                        True
# 65436                     False                       False
#
#       LanguageHaveWorkedWith_Python LanguageHaveWorkedWith_F#  \
# 0                             False                     False
# 1                              True                     False
# 2                             False                     False
# 3                              True                     False
# 4                              True                     False
# ...                             ...                       ...
# 65432                         False                     False
# 65433                         False                     False
# 65434                         False                     False
# 65435                          True                     False
# 65436                          True                     False
#
#       LanguageHaveWorkedWith_Ruby LanguageHaveWorkedWith_Scala  \
# 0                           False                        False
# 1                           False                        False
# 2                           False                        False
# 3                           False                        False
# 4                           False                        False
# ...                           ...                          ...
# 65432                       False                        False
# 65433                       False                        False
# 65434                       False                        False
# 65435                       False                        False
# 65436                       False                        False
#
#       LanguageHaveWorkedWith_Elixir LanguageHaveWorkedWith_Delphi  \
# 0                             False                         False
# 1                             False                         False
# 2                             False                         False
# 3                             False                         False
# 4                             False                         False
# ...                             ...                           ...
# 65432                         False                         False
# 65433                         False                         False
# 65434                         False                         False
# 65435                         False                         False
# 65436                         False                         False
#
#       LanguageHaveWorkedWith_R LanguageHaveWorkedWith_Java
# 0                        False                       False
# 1                        False                        True
# 2                        False                       False
# 3                        False                        True
# 4                        False                       False
# ...                        ...                         ...
# 65432                    False                       False
# 65433                    False                       False
# 65434                    False                       False
# 65435                    False                       False
# 65436                    False                        True
#
# [65437 rows x 164 columns]

# %%
#find the programming language columns
lang_columns = [col for col in lang_df.columns if col.startswith("LanguageHaveWorkedWith_")]
print(lang_columns) #a list with the column names from the lang_df
# Out:
# ['LanguageHaveWorkedWith_Swift', 'LanguageHaveWorkedWith_GDScript', 'LanguageHaveWorkedWith_MATLAB', 'LanguageHaveWorkedWith_Prolog', 'LanguageHaveWorkedWith_MicroPython', 'LanguageHaveWorkedWith_PHP', 'LanguageHaveWorkedWith_Cobol', 'LanguageHaveWorkedWith_Apex', 'LanguageHaveWorkedWith_Solidity', 'LanguageHaveWorkedWith_Nim', 'LanguageHaveWorkedWith_C#', 'LanguageHaveWorkedWith_OCaml', 'LanguageHaveWorkedWith_Crystal', 'LanguageHaveWorkedWith_SQL', 'LanguageHaveWorkedWith_Objective-C', 'LanguageHaveWorkedWith_Erlang', 'LanguageHaveWorkedWith_Julia', 'LanguageHaveWorkedWith_Assembly', 'LanguageHaveWorkedWith_Kotlin', 'LanguageHaveWorkedWith_C', 'LanguageHaveWorkedWith_Groovy', 'LanguageHaveWorkedWith_Clojure', 'LanguageHaveWorkedWith_TypeScript', 'LanguageHaveWorkedWith_Zephyr', 'LanguageHaveWorkedWith_HTML/CSS', 'LanguageHaveWorkedWith_VBA', 'LanguageHaveWorkedWith_Dart', 'LanguageHaveWorkedWith_Bash/Shell (all shells)', 'LanguageHaveWorkedWith_PowerShell', 'LanguageHaveWorkedWith_C++', 'LanguageHaveWorkedWith_Haskell', 'LanguageHaveWorkedWith_Lua', 'LanguageHaveWorkedWith_Visual Basic (.Net)', 'LanguageHaveWorkedWith_Perl', 'LanguageHaveWorkedWith_JavaScript', 'LanguageHaveWorkedWith_Zig', 'LanguageHaveWorkedWith_Fortran', 'LanguageHaveWorkedWith_Lisp', 'LanguageHaveWorkedWith_Ada', 'LanguageHaveWorkedWith_Go', 'LanguageHaveWorkedWith_Rust', 'LanguageHaveWorkedWith_Python', 'LanguageHaveWorkedWith_F#', 'LanguageHaveWorkedWith_Ruby', 'LanguageHaveWorkedWith_Scala', 'LanguageHaveWorkedWith_Elixir', 'LanguageHaveWorkedWith_Delphi', 'LanguageHaveWorkedWith_R', 'LanguageHaveWorkedWith_Java']

# %%
mean_job_satisfaction = {} #create an empty list to save results

for lang_col in lang_columns:
    # Filter rows where the language column is True
    filtered_rows = lang_df[lang_df[lang_col] == True]
    
    # Compute the mean of the job satisfaction column
    mean_satisfaction = filtered_rows['JobSat_scaled'].mean()
    
    # Extract the programming language name from the column name
    lang_name = lang_col.replace("LanguageHaveWorkedWith_", "")
    
    # Store the result in the dictionary
    mean_job_satisfaction[lang_name] = mean_satisfaction

    # saving resultsto a DataFrame
    mean_job_satisfaction_df = pd.DataFrame(
    list(mean_job_satisfaction.items()), columns=["Programming Language", "Mean Job Satisfaction"]
    )


print("Mean Job Satisfaction for Each Programming Language:")
for lang_name, mean in mean_job_satisfaction.items():
    print(f"{lang_name}: {mean}")
# Out:
# Mean Job Satisfaction for Each Programming Language:
# Swift: 3.8092526690391457
# GDScript: 3.726923076923077
# MATLAB: 3.6351063829787233
# Prolog: 3.6149068322981366
# MicroPython: 3.691011235955056
# PHP: 3.7127458396369137
# Cobol: 3.6685082872928176
# Apex: 3.7254098360655736
# Solidity: 3.797427652733119
# Nim: 3.5945945945945947
# C#: 3.728036401820091
# OCaml: 3.8092105263157894
# Crystal: 3.7358490566037736
# SQL: 3.7106308991554893
# Objective-C: 3.8315467075038283
# Erlang: 3.710526315789474
# Julia: 3.667924528301887
# Assembly: 3.7417391304347825
# Kotlin: 3.7759094028826357
# C: 3.7104183757178015
# Groovy: 3.7587681779298547
# Clojure: 3.747967479674797
# TypeScript: 3.7526076916951987
# Zephyr: 3.7875
# HTML/CSS: 3.7097781536659946
# VBA: 3.642156862745098
# Dart: 3.7474566128067024
# Bash/Shell (all shells): 3.705623654907832
# PowerShell: 3.697492163009404
# C++: 3.7113100361508007
# Haskell: 3.748235294117647
# Lua: 3.661697990926766
# Visual Basic (.Net): 3.7031118587047938
# Perl: 3.718926553672316
# JavaScript: 3.7189393939393938
# Zig: 3.710204081632653
# Fortran: 3.68796992481203
# Lisp: 3.685483870967742
# Ada: 3.7058823529411766
# Go: 3.7337931034482756
# Rust: 3.686681844052362
# Python: 3.68892154804395
# F#: 3.8838951310861423
# Ruby: 3.7983963344788085
# Scala: 3.764218009478673
# Elixir: 3.8068350668647843
# Delphi: 3.8090128755364807
# R: 3.6871455576559544
# Java: 3.702427295626288

# %%
print(mean_job_satisfaction_df)
# Out:
#        Programming Language  Mean Job Satisfaction
# 0                     Swift               3.809253
# 1                  GDScript               3.726923
# 2                    MATLAB               3.635106
# 3                    Prolog               3.614907
# 4               MicroPython               3.691011
# 5                       PHP               3.712746
# 6                     Cobol               3.668508
# 7                      Apex               3.725410
# 8                  Solidity               3.797428
# 9                       Nim               3.594595
# 10                       C#               3.728036
# 11                    OCaml               3.809211
# 12                  Crystal               3.735849
# 13                      SQL               3.710631
# 14              Objective-C               3.831547
# 15                   Erlang               3.710526
# 16                    Julia               3.667925
# 17                 Assembly               3.741739
# 18                   Kotlin               3.775909
# 19                        C               3.710418
# 20                   Groovy               3.758768
# 21                  Clojure               3.747967
# 22               TypeScript               3.752608
# 23                   Zephyr               3.787500
# 24                 HTML/CSS               3.709778
# 25                      VBA               3.642157
# 26                     Dart               3.747457
# 27  Bash/Shell (all shells)               3.705624
# 28               PowerShell               3.697492
# 29                      C++               3.711310
# 30                  Haskell               3.748235
# 31                      Lua               3.661698
# 32      Visual Basic (.Net)               3.703112
# 33                     Perl               3.718927
# 34               JavaScript               3.718939
# 35                      Zig               3.710204
# 36                  Fortran               3.687970
# 37                     Lisp               3.685484
# 38                      Ada               3.705882
# 39                       Go               3.733793
# 40                     Rust               3.686682
# 41                   Python               3.688922
# 42                       F#               3.883895
# 43                     Ruby               3.798396
# 44                    Scala               3.764218
# 45                   Elixir               3.806835
# 46                   Delphi               3.809013
# 47                        R               3.687146
# 48                     Java               3.702427

# %%
# Create the bar plot
fig_lang = px.bar(
    mean_job_satisfaction_df, 
    x='Programming Language', 
    y='Mean Job Satisfaction', 
    title='Mean Job Satisfaction by Programming Language',
    labels={'Programming Language': 'Programming Language', 'Mean Job Satisfaction': 'Mean Job Satisfaction'},
    color='Programming Language',  # Optional: adds different colors to the bars
    text='Mean Job Satisfaction'  # Show the mean value on the bars
)

# Update layout for better appearance
fig_lang.update_layout(
    xaxis_title='Programming Language',
    yaxis_title='Mean Job Satisfaction',
    title_x=0.5,  # Center the title
    template='plotly_white',  # Use a clean white background
    showlegend=False
)


fig_lang.show()

# %%
# Step 1: Get the unique categories in the RemoteWork column
work_cat = survey['RemoteWork'].dropna().unique()

# Step 2: Initialize a dictionary to store results
mean_jobsat= {}

# Step 3: Loop through each category and compute the mean manually
for category in work_cat:
    # Filter the rows where RemoteWork matches the current category
    rows_catdf = survey[survey['RemoteWork'] == category]
    
    # Compute the mean of JobSat_scaled for the filtered rows
    mean_satisfaction = rows_catdf['JobSat_scaled'].mean()
    
    # Store the result in the dictionary
    mean_jobsat[category] = mean_satisfaction

# Step 4: Convert the dictionary into a DataFrame (optional)
mean_jobsat_df = pd.DataFrame(
    list(mean_jobsat.items()), 
    columns=['Work Category', 'Mean Job Satisfaction']
)


print("Mean Job Satisfaction by Work Category:")
print(mean_jobsat_df)
# Out:
# Mean Job Satisfaction by Work Category:
#                           Work Category  Mean Job Satisfaction
# 0                                Remote               3.773755
# 1                             In-person               3.569362
# 2  Hybrid (some remote, some in-person)               3.709555

# %% [markdown]
# 10! Bonus: Think of additional interesting statistical questions yourself and find the answers.

# %%
fig_lang = px.line(
    mean_job_satisfaction_df,
    x='Programming Language',
    y='Mean Job Satisfaction',
    title='Trend of Mean Job Satisfaction by Programming Language',
    labels={'Programming Language': 'Programming Language', 'Mean Job Satisfaction': 'Mean Job Satisfaction'},
    markers=True,  # Adds markers to the lines for better visualization
    color_discrete_sequence=['blue']  # Optional: use a single color for simplicity
)

# Update layout for better appearance
fig_lang.update_layout(
    xaxis_title='Programming Language',
    yaxis_title='Mean Job Satisfaction',
    title_x=0.5,  # Center the title
    template='plotly_white'  # Use a clean white background
)

fig_lang.show()

# %%
# Count respondents by country
country_counts = survey['Country'].value_counts().head(10).reset_index()
country_counts.columns = ['Country', 'Count']

# Create a bar chart
fig_country = px.bar(
    country_counts,
    x='Country',
    y='Count',
    title='Top 10 Countries by Number of Respondents',
    labels={'Country': 'Country', 'Count': 'Number of Respondents'},
    color='Country',
    text='Count'
)

# Update layout
fig_country.update_layout(
    xaxis_title='Country',
    yaxis_title='Number of Respondents',
    title_x=0.5,
    template='plotly_white',
    showlegend=False
)


fig_country.show()

# %%
language_counts = survey['LanguageHaveWorkedWith'].dropna().str.split(';').explode().value_counts().reset_index()
language_counts.columns = ['Programming Language', 'Count']

# Create a bar chart
fig_language = px.bar(
    language_counts.head(10),  # Top 10 programming languages
    x='Programming Language',
    y='Count',
    title='Top 10 Programming Languages Used by Respondents',
    labels={'Programming Language': 'Programming Language', 'Count': 'Number of Respondents'},
    color='Programming Language',
    text='Count'
)

# Update layout
fig_language.update_layout(
    xaxis_title='Programming Language',
    yaxis_title='Number of Respondents',
    title_x=0.5,
    template='plotly_white',
    showlegend=False
)


fig_language.show()

# %%
# Calculate the average salary by developer type
avg_salary = survey.groupby('MainBranch')['ConvertedCompYearly'].mean().dropna().reset_index()
avg_salary.columns = ['Developer Type', 'Average Salary']

# Create a bar chart
fig_avg_salary = px.bar(
    avg_salary,
    x='Developer Type',
    y='Average Salary',
    title='Average Salary by Developer Type',
    labels={'Developer Type': 'Developer Type', 'Average Salary': 'Average Salary (USD)'},
    color='Developer Type',
    text='Average Salary'
)

# Update layout
fig_avg_salary.update_layout(
    xaxis_title='Developer Type',
    yaxis_title='Average Salary (USD)',
    title_x=0.5,
    template='plotly_white',
    showlegend=False
)


fig_avg_salary.show()

# %%
# Count learning resources from the 'LearnCode' column
learning_resources = survey['LearnCode'].dropna().str.split(';').explode().value_counts().reset_index()
learning_resources.columns = ['Learning Resource', 'Count']

# Create a bar chart
fig_learning = px.bar(
    learning_resources.head(10),  # Top 10 learning resources
    x='Learning Resource',
    y='Count',
    title='Top 10 Learning Resources for Developers',
    labels={'Learning Resource': 'Learning Resource', 'Count': 'Number of Respondents'},
    color='Learning Resource',
    text='Count'
)

# Update layout
fig_learning.update_layout(
    xaxis_title='Learning Resource',
    yaxis_title='Number of Respondents',
    title_x=0.5,
    template='plotly_white',
    showlegend=False
)


fig_learning.show()

# %%
# Count developer types
dev_type_counts = survey['DevType'].dropna().str.split(';').explode().value_counts().reset_index()
dev_type_counts.columns = ['Developer Type', 'Count']

# Plot the data
fig_devtype = px.bar(
    dev_type_counts.sort_values(by='Count', ascending=True),
    x='Count',
    y='Developer Type',
    title='Most Common Developer Types',
    labels={'Count': 'Number of Respondents', 'Developer Type': 'Developer Type'},
    orientation='h',  # Horizontal bar chart
    color='Developer Type'
)

# Update layout
fig_devtype.update_layout(
    xaxis_title='Number of Respondents',
    yaxis_title='Developer Type',
    title_x=0.5,
    template='plotly_white',
    showlegend=False
)

fig_devtype.show()

# %%
# Filter valid data for salary and developer types
salary_roles = survey[['DevType', 'ConvertedCompYearly']].dropna()
salary_roles = salary_roles[salary_roles['ConvertedCompYearly'] < 300000]  # Exclude extreme outliers
salary_roles = salary_roles[salary_roles['DevType'].notnull()]
salary_roles['DevType'] = salary_roles['DevType'].str.split(';').str[0]  # Take only the first role listed

# Plot the data
fig_salary_roles = px.box(
    salary_roles,
    x='DevType',
    y='ConvertedCompYearly',
    title='Salary Distribution by Developer Role',
    labels={'DevType': 'Developer Role', 'ConvertedCompYearly': 'Salary (USD)'},
    color='DevType'
)

# Update layout
fig_salary_roles.update_layout(
    xaxis_title='Developer Role',
    yaxis_title='Salary (USD)',
    title_x=0.5,
    template='plotly_white'
)

fig_salary_roles.show()

# %%
# Count platforms
platform_counts = survey['PlatformHaveWorkedWith'].dropna().str.split(';').explode().value_counts().reset_index()
platform_counts.columns = ['Platform', 'Count']

# Plot the data
fig_platforms = px.bar(
    platform_counts.head(10),
    x='Platform',
    y='Count',
    title='Top 10 Platforms Used by Respondents',
    labels={'Platform': 'Platform', 'Count': 'Number of Respondents'},
    color='Platform',
    text='Count'
)

# Update layout
fig_platforms.update_layout(
    xaxis_title='Platform',
    yaxis_title='Number of Respondents',
    title_x=0.5,
    template='plotly_white',
    showlegend=False
)

fig_platforms.show()

# %%
# Filter for professional developers
professional_developers = survey[survey['MainBranch'] == 'I am a developer by profession']

# Count respondents per country
country_counts = professional_developers['Country'].value_counts().reset_index()
country_counts.columns = ['Country', 'Count']

# Plot the top 10 countries
fig_countries = px.bar(
    country_counts.head(10),
    x='Country',
    y='Count',
    title='Top 10 Countries with the Most Professional Developers',
    labels={'Country': 'Country', 'Count': 'Number of Developers'},
    color='Country',
    text='Count'
)

# Update layout
fig_countries.update_layout(
    xaxis_title='Country',
    yaxis_title='Number of Developers',
    title_x=0.5,
    template='plotly_white',
    showlegend=False
)

fig_countries.show()

# %%
# Count desired technologies
wanted_technologies = survey['LanguageWantToWorkWith'].dropna().str.split(';').explode().value_counts().reset_index()
wanted_technologies.columns = ['Technology', 'Count']

# Plot the top 10 desired technologies
fig_wanted_tech = px.bar(
    wanted_technologies.head(10),
    x='Technology',
    y='Count',
    title='Top 10 Technologies Respondents Want to Work With',
    labels={'Technology': 'Technology', 'Count': 'Number of Respondents'},
    color='Technology',
    text='Count'
)

# Update layout
fig_wanted_tech.update_layout(
    xaxis_title='Technology',
    yaxis_title='Number of Respondents',
    title_x=0.5,
    template='plotly_white',
    showlegend=False
)

fig_wanted_tech.show()

# %%
# Count the frequency of coding activities
coding_activities = survey['CodingActivities'].dropna().str.split(';').explode().value_counts().reset_index()
coding_activities.columns = ['Coding Activity', 'Count']

# Plot the data
fig_coding_activities = px.bar(
    coding_activities.head(10),
    x='Coding Activity',
    y='Count',
    title='Most Common Coding Activities Among Developers',
    labels={'Coding Activity': 'Activity', 'Count': 'Number of Respondents'},
    color='Coding Activity',
    text='Count'
)

# Update layout
fig_coding_activities.update_layout(
    xaxis_title='Activity',
    yaxis_title='Number of Respondents',
    title_x=0.5,
    template='plotly_white',
    showlegend=False
)

fig_coding_activities.show()

# %%
# Count the databases worked with
databases_used = survey['DatabaseHaveWorkedWith'].dropna().str.split(';').explode().value_counts().reset_index()
databases_used.columns = ['Database', 'Count']

# Plot the data
fig_databases_used = px.pie(
    databases_used,
    names='Database',
    values='Count',
    title='Most Common Databases Used by Respondents',
    color_discrete_sequence=px.colors.sequential.RdBu
)

fig_databases_used.show()
